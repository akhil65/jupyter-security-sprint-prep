# %% [markdown]
# # Training Playground — Example Notebook
#
# This notebook is intentionally vulnerable for demonstration purposes.
# It shows what **nb-defense** / an AI-SPM scanner would flag:
# - Hardcoded PII in cell outputs
# - API keys embedded in code cells
#
# **Do not use these patterns in real notebooks.**

# %%
# TRAINING DEMO: PII exposed in cell output.
# nb-defense / AI-SPM scanners detect patterns like this in notebook outputs.
user_data = {
    'email': 'john.doe@example.com',
    'ssn': '123-45-6789',       # fake SSN for demo
    'card': '4111111111111111'  # Luhn-valid test card number
}
print(f"User: {user_data['email']} | SSN: {user_data['ssn']} | Card: {user_data['card']}")
# Out:
# User: john.doe@example.com | SSN: 123-45-6789 | Card: 4111111111111111

# %%
# TRAINING DEMO: Hardcoded credential in notebook cell.
# A real secret scanner (gitleaks, trufflehog) and nb-defense would flag this.
api_key = 'AKIAIOSFODNN7EXAMPLE'  # fake AWS key pattern — not a real credential
